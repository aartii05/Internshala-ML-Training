# %%
import pandas as pd

# %%
df=pd.read_csv("/Users/bhaveshgoyal/Desktop/Internshala-Training/read_csv/chennai_house_price_prediction.csv")

# %%
df.head()
# Out:
#    PRT_ID        AREA  INT_SQFT  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  N_ROOM  \
# 0  P03210  Karapakkam      1004            131        1.0         1.0       3
# 1  P09411  Anna Nagar      1986             26        2.0         1.0       5
# 2  P01812       Adyar       909             70        1.0         1.0       3
# 3  P05346   Velachery      1855             14        3.0         2.0       5
# 4  P06210  Karapakkam      1226             84        1.0         1.0       3
#
#   SALE_COND PARK_FACIL   BUILDTYPE UTILITY_AVAIL  STREET MZZONE  QS_ROOMS  \
# 0  AbNormal        Yes  Commercial        AllPub   Paved      A       4.0
# 1  AbNormal         No  Commercial        AllPub  Gravel     RH       4.9
# 2  AbNormal        Yes  Commercial           ELO  Gravel     RL       4.1
# 3    Family         No      Others       NoSewr    Paved      I       4.7
# 4  AbNormal        Yes      Others        AllPub  Gravel      C       3.0
#
# ...

# %% [markdown]
# ## - Drop duplicates if any
# ## -Fill the missing values
# ## -Corect data types
# ## -Fill the spelling errors in variables

# %% [markdown]
# ## - Drop duplicates if any

# %%
df.drop_duplicates()
# Out:
#       PRT_ID        AREA  INT_SQFT  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  \
# 0     P03210  Karapakkam      1004            131        1.0         1.0
# 1     P09411  Anna Nagar      1986             26        2.0         1.0
# 2     P01812       Adyar       909             70        1.0         1.0
# 3     P05346   Velachery      1855             14        3.0         2.0
# 4     P06210  Karapakkam      1226             84        1.0         1.0
# ...      ...         ...       ...            ...        ...         ...
# 7104  P03834  Karapakkam       598             51        1.0         1.0
# 7105  P10000   Velachery      1897             52        3.0         2.0
# 7106  P09594   Velachery      1614            152        2.0         1.0
# 7107  P06508  Karapakkam       787             40        1.0         1.0
# 7108  P09794   Velachery      1896            156        3.0         2.0
#
#       N_ROOM    SALE_COND PARK_FACIL   BUILDTYPE UTILITY_AVAIL     STREET  \
# ...

# %%
df.drop_duplicates().shape
# Out:
# (7109, 19)

# %%
df.shape
# Out:
# (7109, 19)

# %% [markdown]
# ### We have no duplicate hence the shape value did not change

# %% [markdown]
# # Missing Values

# %%
df.isnull().sum()
# Out:
# PRT_ID            0
# AREA              0
# INT_SQFT          0
# DIST_MAINROAD     0
# N_BEDROOM         1
# N_BATHROOM        5
# N_ROOM            0
# SALE_COND         0
# PARK_FACIL        0
# BUILDTYPE         0
# UTILITY_AVAIL     0
# STREET            0
# MZZONE            0
# QS_ROOMS          0
# QS_BATHROOM       0
# QS_BEDROOM        0
# QS_OVERALL       48
# COMMIS            0
# SALES_PRICE       0
# dtype: int64

# %% [markdown]
# ## Different ways to deal with missing values
# ## -Remove rows with missing values
# ## -Mean or median in case of continuous variables
# ## -With mode in case of categorical variables
# ## -Using other independant variables

# %% [markdown]
# ## Different ways to deal with missing values

# %%
df.dropna(axis=0,how='any') # axis=0 for rows
# Out:
#       PRT_ID        AREA  INT_SQFT  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  \
# 0     P03210  Karapakkam      1004            131        1.0         1.0
# 1     P09411  Anna Nagar      1986             26        2.0         1.0
# 2     P01812       Adyar       909             70        1.0         1.0
# 3     P05346   Velachery      1855             14        3.0         2.0
# 4     P06210  Karapakkam      1226             84        1.0         1.0
# ...      ...         ...       ...            ...        ...         ...
# 7104  P03834  Karapakkam       598             51        1.0         1.0
# 7105  P10000   Velachery      1897             52        3.0         2.0
# 7106  P09594   Velachery      1614            152        2.0         1.0
# 7107  P06508  Karapakkam       787             40        1.0         1.0
# 7108  P09794   Velachery      1896            156        3.0         2.0
#
#       N_ROOM    SALE_COND PARK_FACIL   BUILDTYPE UTILITY_AVAIL     STREET  \
# ...

# %%
df.shape
# Out:
# (7109, 19)

# %% [markdown]
# ### -When axis is set to 0,rows are dropped
# ### -54 rows are removed

# %%
df.dropna(axis=1,how='any') # axis=1 for cols
# Out:
#       PRT_ID        AREA  INT_SQFT  DIST_MAINROAD  N_ROOM    SALE_COND  \
# 0     P03210  Karapakkam      1004            131       3     AbNormal
# 1     P09411  Anna Nagar      1986             26       5     AbNormal
# 2     P01812       Adyar       909             70       3     AbNormal
# 3     P05346   Velachery      1855             14       5       Family
# 4     P06210  Karapakkam      1226             84       3     AbNormal
# ...      ...         ...       ...            ...     ...          ...
# 7104  P03834  Karapakkam       598             51       2      AdjLand
# 7105  P10000   Velachery      1897             52       5       Family
# 7106  P09594   Velachery      1614            152       4  Normal Sale
# 7107  P06508  Karapakkam       787             40       2      Partial
# 7108  P09794   Velachery      1896            156       5      Partial
#
#      PARK_FACIL   BUILDTYPE UTILITY_AVAIL     STREET MZZONE  QS_ROOMS  \
# ...

# %%
df.shape
# Out:
# (7109, 19)

# %% [markdown]
# ### -When axis is set to 1,cols are dropped
# ### -3 cols are removed
# ### -To avoid loss of data,we can use other ways of imputation

# %% [markdown]
# # 1. N_BEDROOM

# %%
df['N_BEDROOM'].mode()
# Out:
# 0    1.0
# dtype: float64

# %%
df['N_BEDROOM'].fillna(value=(df['N_BEDROOM'].mode()[0]),inplace=True)

# %% [markdown]
# # 2. QS_OVERALL

# %%
df[['QS_ROOMS','QS_BATHROOM','QS_BEDROOM','QS_OVERALL']].head()
# Out:
#    QS_ROOMS  QS_BATHROOM  QS_BEDROOM  QS_OVERALL
# 0       4.0          3.9         4.9       4.330
# 1       4.9          4.2         2.5       3.765
# 2       4.1          3.8         2.2       3.090
# 3       4.7          3.9         3.6       4.010
# 4       3.0          2.5         4.1       3.290

# %%
temp= (df['QS_ROOMS'] + df['QS_BATHROOM']+ df['QS_BEDROOM'])/3
pd.concat([df['QS_ROOMS'] ,df['QS_BATHROOM'],df['QS_BEDROOM'],temp],axis=1).head(10)
# Out:
#    QS_ROOMS  QS_BATHROOM  QS_BEDROOM         0
# 0       4.0          3.9         4.9  4.266667
# 1       4.9          4.2         2.5  3.866667
# 2       4.1          3.8         2.2  3.366667
# 3       4.7          3.9         3.6  4.066667
# 4       3.0          2.5         4.1  3.200000
# 5       4.5          2.6         3.1  3.400000
# 6       3.6          2.1         2.5  2.733333
# 7       2.4          4.5         2.1  3.000000
# 8       2.9          3.7         4.0  3.533333
# 9       3.1          3.1         3.3  3.166667

# %% [markdown]
# ## - Imputomng missing values with the help of other 'quality score' cols
# ## -Additionaly we can assign higher weights to n_bedroom and lower to n_bathroom

# %%
df.loc[df['QS_OVERALL'].isnull()==True].shape
# Out:
# (48, 19)

# %%
def filln_na(x):
    return ((x['QS_ROOMS']+x['QS_BATHROOM']+x['QS_BEDROOM'])/3)

# %% [markdown]
# # DATA TYPES

# %%
df.dtypes
# Out:
# PRT_ID            object
# AREA              object
# INT_SQFT           int64
# DIST_MAINROAD      int64
# N_BEDROOM        float64
# N_BATHROOM       float64
# N_ROOM             int64
# SALE_COND         object
# PARK_FACIL        object
# BUILDTYPE         object
# UTILITY_AVAIL     object
# STREET            object
# MZZONE            object
# QS_ROOMS         float64
# QS_BATHROOM      float64
# QS_BEDROOM       float64
# QS_OVERALL       float64
# COMMIS             int64
# SALES_PRICE        int64
# dtype: object

# %%
# data type of n_bedroom,n_bathroom

df=df.astype({"N_BEDROOM":'object','N_ROOM':'object','N_BATHROOM':'object'})

# %%
df.dtypes
# Out:
# PRT_ID            object
# AREA              object
# INT_SQFT           int64
# DIST_MAINROAD      int64
# N_BEDROOM         object
# N_BATHROOM        object
# N_ROOM            object
# SALE_COND         object
# PARK_FACIL        object
# BUILDTYPE         object
# UTILITY_AVAIL     object
# STREET            object
# MZZONE            object
# QS_ROOMS         float64
# QS_BATHROOM      float64
# QS_BEDROOM       float64
# QS_OVERALL       float64
# COMMIS             int64
# SALES_PRICE        int64
# dtype: object

# %% [markdown]
# ### astype() is used to change the datatypes

# %% [markdown]
# # Replace Categories

# %%
temp=['AREA','N_BEDROOM','N_ROOM','N_BATHROOM','SALE_COND','PARK_FACIL','BUILDTYPE','UTILITY_AVAIL','STREET','MIZZONE']
for i in temp:
    print('*************** VALUE COUNT IN i ******************')
    print(df[i].value_counts())
    print('')
# Out:
# *************** VALUE COUNT IN i ******************
# Chrompet      1681
# Karapakkam    1363
# KK Nagar       996
# Velachery      979
# Anna Nagar     783
# Adyar          773
# T Nagar        496
# Chrompt          9
# Chrmpet          6
# Chormpet         6
# TNagar           5
# Ana Nagar        3
# Karapakam        3
# Velchery         2
# Ann Nagar        2
# Adyr             1
# KKNagar          1
# Name: AREA, dtype: int64
#
# *************** VALUE COUNT IN i ******************
# 1.0    3796
# 2.0    2352
# 3.0     707
# 4.0     254
# Name: N_BEDROOM, dtype: int64
#
# *************** VALUE COUNT IN i ******************
# 4    2563
# 3    2125
# 5    1246
# 2     921
# 6     254
# Name: N_ROOM, dtype: int64
#
# *************** VALUE COUNT IN i ******************
# 1.0    5589
# 2.0    1515
# Name: N_BATHROOM, dtype: int64
#
# *************** VALUE COUNT IN i ******************
# AdjLand        1433
# Partial        1429
# Normal Sale    1423
# AbNormal       1406
# ...

# %% [markdown]
# ## Update names in
# ## - AREA
# ## -SALE_COND
# ## -PARK_FACIL
# ## -BUILDTYPE
# ## -UTILITY_AVAIL
# ## -STREET

# %%
df['PARK_FACIL'].replace({'NOO':'No'},inplace=True)
df['PARK_FACIL'].value_counts()
# Out:
# Yes    3587
# No     3520
# Noo       2
# Name: PARK_FACIL, dtype: int64
